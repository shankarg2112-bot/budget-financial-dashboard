# %%
#financial side — pulling Happiest Minds' sales/profit trend and the peer ratio comparison.
import pandas as pd
pl2 = pd.read_csv('Annual_P_L_1_clean.csv')
pl2
#Happiest Minds' Sales grew from 1429.29 → 1624.66 (+13.7%),
#and it has the highest profit in the group despite not having the highest sales — solid operating efficiency (OPM 20.67%, second only to Newgen).
# Out:
#                Name                               Industry    Sales  \
# 0     Cigniti Tech.  Computers - Software - Medium / Small  1815.01
# 1  Datamatics Glob.  Computers - Software - Medium / Small  1549.89
# 2    Happiest Minds  Computers - Software - Medium / Small  1624.66
# 3   Newgen Software  Computers - Software - Medium / Small  1136.12
# 4   R Systems Intl.  Computers - Software - Medium / Small  1697.09
#
#    Sales last year  Sales preceding year  Profit after tax  Net profit    OPM  \
# 0          1815.01               1647.58            165.59      165.59  12.22
# 1          1549.89               1459.19            197.13      197.13  15.74
# 2          1624.66               1429.29            238.36      248.39  20.67
# 3          1136.12                887.80            237.34      237.34  23.66
# 4          1684.52               1515.83            131.77      131.77  14.78
#
#    OPM last year
# 0          12.22
# 1          15.74
# 2          20.67
# ...

# %%
#Now let's pull the ratios file to check liquidity, leverage, and ROE:
r1 = pd.read_csv('ratios_1_clean.csv')
r1
#Happiest Minds has the highest Debt-to-Equity in the peer group (0.35 vs everyone else under 0.21) —
#the one relative caution flag. Its Quick Ratio (3.14) is healthy but on the lower-middle end (only R Systems is lower).
# Out:
#                Name  Debt to equity  Return on equity  Quick ratio
# 0     Cigniti Tech.            0.08             24.95         3.67
# 1  Datamatics Glob.            0.01             17.32         4.90
# 2    Happiest Minds            0.35             20.56         3.14
# 3   Newgen Software            0.04             22.95         3.87
# 4   R Systems Intl.            0.21             24.28         1.70

# %%
#Now let's pull the last piece — Balance Sheet, for cash position and Current Ratio:
bs = pd.read_csv('Balance_Sheet_clean.csv')
om = pd.read_csv('other_metrics_clean.csv')
bs.merge(om, on='Name')
#Happiest Minds' cash reserve (₹1,336.53 Cr) is massive compared to every peer — over 5x the next highest (R Systems at 251.72).
#T#hat's what makes the ~₹8.15 Cr budget overspend a non-issue financially — their cash alone could absorb it over 160 times.
# Out:
#                Name    Debt  Current assets  Current liabilities  \
# 0     Cigniti Tech.   57.24          863.12               235.14
# 1  Datamatics Glob.   17.38          945.20               192.94
# 2    Happiest Minds  512.19         1777.77               566.98
# 3   Newgen Software   41.69         1115.56               288.08
# 4   R Systems Intl.  131.18          626.17               368.30
#
#    Cash Equivalents  Current ratio
# 0            160.47           3.67
# 1            131.25           4.90
# 2           1336.53           3.14
# 3            250.14           3.87
# 4            251.72           1.70

# %%
cf = pd.read_csv('cash_flow_clean.csv')
cf
# Out:
#                Name  Cash from operations last year  Free cash flow last year  \
# 0     Cigniti Tech.                          129.42                    124.40
# 1  Datamatics Glob.                          183.87                    174.72
# 2    Happiest Minds                          212.56                    202.30
# 3   Newgen Software                          263.87                    250.43
# 4   R Systems Intl.                          211.36                    192.67
#
#    Net cash flow last year
# 0                    51.80
# 1                   -33.94
# 2                    38.98
# 3                     2.69
# 4                   -48.88

# %%
import os
print(os.getcwd())  # shows your current working folder
os.listdir()          # lists all files in it
# Out:
# C:\Users\Shankar
# ['-1.14-windows.xml',
#  '.anaconda',
#  '.augment',
#  '.bash_history',
#  '.cache',
#  '.claude',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.cursor',
#  '.docker',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.local',
#  '.matplotlib',
#  '.ollama',
#  '.spyder-py3',
#  '.VirtualBox',
#  '.virtual_documents',
#  '.vscode',
#  '.vscode-shared',
#  '14-1.ipynb',
#  '14-2.ipynb',
#  'access.log.txt',
#  'anaconda3',
#  'Annual_P_L_1_5companies.csv',
#  'Annual_P_L_1_clean.csv',
#  'Annual_P_L_2_5companies.csv',
#  'Annual_P_L_2_clean.csv',
#  'AppData',
#  'Application Data',
#  'Balance_Sheet_5companies.csv',
#  'Balance_Sheet_clean.csv',
#  'books-project',
#  'Budget vs Actual.csv',
#  'CADB1.ipynb',
#  'cash_flow_clean.csv',
#  'cash_flow_statments_5companies.csv',
#  'Contacts',
#  'Cookies',
#  'Crop.ipynb',
#  'data collection',
#  'data_folder',
#  'Documents',
#  'Downloads',
#  'DP.ipynb',
#  'Favorites',
# ...
